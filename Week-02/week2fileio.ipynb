# %%
file1=open("student.txt","w")
file1.write("Farah\nAli\nSara\nAhmad\nFatima")
file1.close()

# %%
file1=open("student.txt","r")
print(file1.read())
file1.close()
# Out:
# Farah
# Ali
# Sara
# Ahmad
# Fatima

# %%
file1=open("student.txt","a")
file1.write("\nSubhan")
file1.close
# Out:
# <function TextIOWrapper.close()>

# %%
file1=open("student.txt","r")
print(file1.read())
file1.close()
# Out:
# Farah
# Ali
# Sara
# Ahmad
# Fatima

# %%
count=0
data=True
line_no=1
with open("student.txt","r") as file1:
    while data:
        data=file1.readline()
        count+=1
        line_no+=1

print(count)
# Out:
# 6

# %%
data=True
line_no=1


with open("student.txt","r") as file1:
    data=print(file1.readline())
    while data:
        if name.starts("a") in data:
            print(name)
            line_no+=1
# Out:
# Farah

# %%
file2=open("marks.txt","w")
file2.write("85\n90\n78\n92\n88")
file2.close()

# %%
file2=open("marks.txt","r")
print(file2.read())
file2.close()
# Out:
# 85
# 90
# 78
# 92
# 88

# %%
newstudent=input("Enter the name")
file1=open("student.txt","a")
file1.write(newstudent)
file1.close
# Out:
# Enter the name subhan
# <function TextIOWrapper.close()>

# %%
file1=open("student.txt","r")
print(file1.read())
file1.close
# Out:
# Farah
# Ali
# Sara
# Ahmad
# Fatima
# <function TextIOWrapper.close()>

# %%
student="Farah"
data=True

with open("student.txt","r") as file1:
    while data:
        data=file1.read()
        if student in data:
            print("student found")
            
        else:
            print("student not found")
# Out:
# student found
# student not found

# %%
select=input("enter the one option:1.Add Student 2. View Students3. Search Student 4. Exit")
print(select)

if select== "add student":
    studentname=input("enter the name")
    file1=open("student.txt","w")
    file1.close()

elif select=="view students":
     file1=open("student.txt","r")
     print(file1.read())
     file1.close()
    
elif select=="search student":
    student=input("enter the name")
    file1=open("student.txt","r")
    data=file1.readline()
    if (student 
        print("found")
        
    else:
        print("not found")
    file1.close()

else:
    file1.close()
# Out:
# enter the one option:1.Add Student 2. View Students3. Search Student 4. Exit search student
# search student
# enter the name ali
# not found
