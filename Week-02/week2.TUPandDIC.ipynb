# %%
cities=("Islamabad", "Lahore","Karachi", "Peshawar","Quetta")
print(type(cities), cities)
# Out:
# <class 'tuple'> ('Islamabad', 'Lahore', 'Karachi', 'Peshawar', 'Quetta')

# %%
print(cities[0])
print(cities[-1])
print(cities[2])
# Out:
# Islamabad
# Quetta
# Karachi

# %%
print(cities[1:4]) #slicing of a tuple results in a new tuple (not change the original one)
# Out:
# ('Lahore', 'Karachi', 'Peshawar')

# %%
print(cities.index("Karachi"))
# Out:
# 2

# %%
numbers = (1,5,8,5,10,5,7)
print(numbers.count(5))
# Out:
# 3

# %%
student = ("Farah",32,"Pakistan")
(Name, Age, Country)= student
print(Name)
print(Age)
print(Country)
# Out:
# Farah
# 32
# Pakistan

# %%
cities[0]="Multan" #tuples are immutable that's why we got this error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 cities[0]="Multan"
#
# TypeError: 'tuple' object does not support item assignment

# %%
student={"name":"Farah","age":32, "course":"Data Science"}
print(type(student), student)
# Out:
# <class 'dict'> {'name': 'Farah', 'age': 32, 'course': 'Data Science'}

# %%
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'course'])

# %%
for key in student.keys():
    print(student[key])
# Out:
# Farah
# 32
# Data Science

# %%
student["age"]=33
print(student)
# Out:
# {'name': 'Farah', 'age': 33, 'course': 'Data Science'}

# %%
student.update({"city":"Islamabad"})

# %%
print(student)
# Out:
# {'name': 'Farah', 'age': 33, 'course': 'Data Science', 'city': 'Islamabad'}

# %%
for items in student.keys():
    print(items)
# Out:
# name
# age
# course
# city

# %%
for key in student.keys():
    print(student[key])
# Out:
# Farah
# 33
# Data Science
# Islamabad

# %%
for key, value in student.items():
    print(key,":", value)
# Out:
# name : Farah
# age : 33
# course : Data Science
# city : Islamabad

# %%
student.pop("course")
# Out:
# 'Data Science'

# %%
print(student)
# Out:
# {'name': 'Farah', 'age': 33, 'city': 'Islamabad'}

# %%
key="city"
if key in student:
    print("city found")

else:
    print("city not found")
# Out:
# city found

# %%
key=input("Enter the key")
if key in student:
    print(student.get(key))
# Out:
# Enter the key name
# Farah

# %%
marks = { "Ali":85, "Sara":92, "Ahmed":78, "Fatima":88, "Farah":95}
print(marks.values())
# Out:
# dict_values([85, 92, 78, 88, 95])

# %%
max(marks.values())
# Out:
# 95

# %%
min(marks.values())
# Out:
# 78

# %%
average=sum(marks.values())/len(marks)
print(average)
# Out:
# 87.6

# %%
count=0

for value in marks.values():
    if value>=80:
        count +=1

print(count)
# Out:
# 4

# %%
name=input("Enter the name")
age=int(input("Enter the age"))
course=input("Enter the course")
city=input("Enter the city")

info={"name": name, "age":age , "course":course, "city":city}
print(info)
# Out:
# Enter the name farah
# Enter the age 32
# Enter the course data science
# Enter the city islamabad
# {'name': 'farah', 'age': 32, 'course': 'data science', 'city': 'islamabad'}

# %%
print("------- Student Card -------")
for values, keys in info.items():
    print(values,":",keys)

print("-----------------------------")
# Out:
# ------- Student Card -------
# name : farah
# age : 32
# course : data science
# city : islamabad
# -----------------------------

# %%
updatedcity=input("DO you want to change your city")
newcity=input("enter the new city")
# Out:
# DO you want to change your city yes
# enter the new city lahore

# %%
city= newcity

# %%
print(info)
# Out:
# {'name': 'farah', 'age': 32, 'course': 'data science', 'city': 'lahore'}

# %%
print("------- Student Card -------")
for values, keys in info.items():
    print(values,":",keys)

print("-----------------------------")
# Out:
# ------- Student Card -------
# name : farah
# age : 32
# course : data science
# city : lahore
# -----------------------------

# %%
petrol = { "January":252, "February":258, "March":264, "April":270}

petrol.values()
# Out:
# dict_values([252, 258, 264, 270])

# %%
min(petrol.values())
# Out:
# 252

# %%
max(petrol.values())
# Out:
# 270

# %%
average=sum(petrol.values())/4
print(average)
# Out:
# 261.0
