# %%
a=int(input("Enter the num"))
b=int(input("Enter the num"))
try:
    print(a/b)
    
except ZeroDivisionError:
            print("Error: You cannot divide by zero!")
# Out:
# Enter the num 7
# Enter the num 0
# Error: You cannot divide by zero!

# %%
a=input("Enter the num")
b=input("Enter the num")
try:
    print(int(a)/int(b))
    
except ZeroDivisionError:
    print("Error: You cannot divide by zero!")

except ValueError:
    print("Error: Please enter a valid integer")
# Out:
# Enter the num 7.7
# Enter the num 9
# Error: Please enter a valid integer

# %%
ageyear=input("Enter your year")
agemonth=input("Enter your month")

try:
    print(f"My age is {int(ageyear)} year and {int(agemonth)} month")
except:
    print("Invalid input")
# Out:
# Enter your year 8.8
# Enter your month 9
# Invalid input

# %%
try:
    with open("farah.txt","r") as file:
        print(file.read())
          
except FileNotFoundError:
    print("Error: File is not available")
# Out:
# Error: File is not available

# %%
try:
    with open("farah.txt","r") as file:
        print(file.read())
          
except FileNotFoundError:
    print("Error: File is not available")

finally:
    with open("student.txt","r") as file:
        print(file.read())
# Out:
# Error: File is not available
# Farah
# Ali
# Sara
# Ahmad
# Fatima

# %%
try:
    name=input("Enter the num")
    fruits=["apple", "cheery", "banana"]
    if name in fruits:
        print(name)
    
except ValueError:
    print("Error: Num is not an integer")
# Out:
# Enter the num mango

# %%
try:
    a=input("Enter the num")
    b=input("Enetr the num")
    operators=input("Enter the operators")

    if operators== "+":
        print(int(a)+int(b))
    elif operators== "-":
        print(int(a)-int(b))
    elif operators== "*":
        print(int(a)*int(b))
    else:
        print(int(a)%int(b))

except:
    print("Invalid Integer")
# Out:
# Enter the num 6
# Enetr the num 7.9
# Enter the operators +
# Invalid Integer

# %%
indriveride=input("select a ride from the given option 1.Economy 2. Comfort 3.Fastest")
fare=input("select a ride from the given option 1.600 2. 800 3.1000")

if (600<=int(fare)<=1000):
    print("accept")
else:
    print("cancel")
# Out:
# select a ride from the given option 1.Economy 2. Comfort 3.Fastest economy
# select a ride from the given option 1.600 2. 800 3.1000 900
# accept
