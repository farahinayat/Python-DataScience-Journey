# %%
name="Farah Inayat"
print(name)
print(name[0])
print(name[-1])
print(name[:5])
print(name[-6:])
# Out:
# Farah Inayat
# F
# t
# Farah
# Inayat

# %%
str1="python programming"
print(str1)
print(str1.upper())
print(str1.lower())
print(str1.title())
# Out:
# python programming
# PYTHON PROGRAMMING
# python programming
# Python Programming

# %%
str2="banana"
print(str2)
print(str2.count("a"))
# Out:
# banana
# 3

# %%
str3="i like jave"
print(str3)
print(str3.replace("jave","python"))
# Out:
# i like jave
# i like python

# %%
str4=input("Enter the intro:")
print(str4)
print(len(str4))
print(str4.split())
# Out:
# Enter the intro: I am Farah.
# I am Farah.
# 11
# ['I', 'am', 'Farah.']

# %%
print(str4.startswith("p"))
# Out:
# False

# %%
email="farahinayat@gamil.com"
print(email.endswith("com"))
# Out:
# True

# %%
print(str1[::-1])
# Out:
# gnimmargorp nohtyp

# %%
for char in str1:
    print(char)
# Out:
# p
# y
# t
# h
# o
# n
#
# p
# r
# o
# g
# r
# a
# m
# m
# i
# n
# g

# %%
username=input("Enter the name")
email=input("Enter the email")
password=input("Enter the password")

print("Welcome", username)

if email.endswith(".com"):
    print("Email:", email)
else:
    print("Invalid email")
    
print("Password length:" "8 characters")
# Out:
# Enter the name farah
# Enter the email farah@gmail
# Enter the password 123456
# Welcome farah
# Invalid email
# Password length:8 characters

# %%
str6="apple"
print(str6)
# Out:
# apple

# %%
rev_str6=print(str6[::-1])
# Out:
# elppa

# %%
if str6==rev_str6:
    print("it is palindrome")
else:
    print("it is not palindrome")
# Out:
# it is not palindrome
