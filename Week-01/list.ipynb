# %%
fruits= ["apple","banana","cherry","guava","grapes"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'guava', 'grapes']

# %%
print(fruits[0])
print(fruits[-1])
# Out:
# apple
# grapes

# %%
fruits.append("mango")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'guava', 'grapes', 'mango', 'mango']

# %% [raw]
# fruits.remove("mango")
# print(fruits)

# %%
fruits.sort()
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'grapes', 'guava']

# %%
fruits.reverse()
print(fruits)
# Out:
# ['guava', 'grapes', 'cherry', 'banana', 'apple']

# %%
for items in fruits:
    print(items)
# Out:
# apple
# banana
# cherry
# grapes
# guava

# %%
len(fruits)
# Out:
# 5

# %%
num=[2,4,5,6,7,9,12]
print(num)
# Out:
# [2, 4, 5, 6, 7, 9, 12]

# %%
min(num)
# Out:
# 2

# %%
max(num)
# Out:
# 12

# %%
sum(num)
# Out:
# 45

# %%
for i in num:
    if (i%2==0):
        print(i)
# Out:
# 2
# 4
# 6
# 12
