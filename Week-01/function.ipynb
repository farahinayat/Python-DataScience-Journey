# %%
def name():
    print("hello farah")
name()
# Out:
# hello farah

# %%
def sum(a,b):
    sum=a+b
    print(sum)

sum(2,3)
# Out:
# 5

# %%
def square(n):
    square=n*n
    print(square)

square(5)
# Out:
# 25

# %%
def evenodd(n):
    if (n%2==0):
        print(n, "is even")
    else:
        print(n, "is odd")

evenodd(6)
# Out:
# 6 is even

# %%
def table(n):
    for i in range(1,11):
        print(n*i)

table(5)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
def cube(n):
    print(n*n*n)

cube(3)
# Out:
# 27
